# %% [markdown]
# # Preprocessing and clustering 2k Glioblatoma Multiforme cells

# %% [markdown]
# In May 2017, this started out as a demonstration that Scanpy would allow to reproduce most of Seurat's [guided clustering tutorial](http://satijalab.org/seurat/pbmc3k_tutorial.html) ([Satija et al., 2015](https://doi.org/10.1038/nbt.3192)).
#
# We gratefully acknowledge Seurat's authors for the tutorial! In the meanwhile, we have added and removed a few pieces.
#
# The data consist of *3k PBMCs from a Healthy Donor* and are freely available from 10x Genomics ([here](http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz) from this [webpage](https://support.10xgenomics.com/single-cell-gene-expression/datasets/1.1.0/pbmc3k)). On a unix system, you can uncomment and run the following to download and unpack the data. The last line creates a directory for writing processed data.

# %%
# !mkdir data
# !wget http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz -O data/pbmc3k_filtered_gene_bc_matrices.tar.gz
# !cd data; tar -xzf pbmc3k_filtered_gene_bc_matrices.tar.gz
# !mkdir write

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# Download the notebook by clicking on the _Edit on GitHub_ button. On GitHub, you can download using the _Raw_ button via right-click and _Save Link As_. Alternatively, download the whole [scanpy-tutorial](https://github.com/theislab/scanpy-tutorials) repository.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# In Jupyter notebooks and lab, you can see the documentation for a python function by hitting ``SHIFT + TAB``. Hit it twice to expand the view.
#
# </div>

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.9.1 anndata==0.8.0 umap==0.5.3 numpy==1.21.5 scipy==1.7.3 pandas==1.4.2 scikit-learn==1.0.2 statsmodels==0.13.2 python-igraph==0.10.2 louvain==0.8.0 pynndescent==0.5.8

# %%
results_file = 'write/2K_Brain_Tumor_filtered_feature_bc_matrix.h5ad'  # the file that will store the analysis results

# %% [markdown]
# Read in the count matrix into an [AnnData](https://anndata.readthedocs.io/en/latest/anndata.AnnData.html) object, which holds many slots for annotations and different representations of the data. It also comes with its own HDF5-based file format: `.h5ad`.

# %%
adata = sc.read_10x_mtx(
    'data/2K_Brain_Tumor_filtered_feature_bc_matrix',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)                              # write a cache file for faster subsequent reading
# Out:
# ... reading from cache file cache\data-2K_Brain_Tumor_filtered_feature_bc_matrix-matrix.h5ad

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1615 × 36601
#     var: 'gene_ids', 'feature_types'

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# See [anndata-tutorials/getting-started](https://anndata-tutorials.readthedocs.io/en/latest/getting-started.html) for a more comprehensive introduction to `AnnData`.
#
# </div>

# %%
adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1615 × 36601
#     var: 'gene_ids', 'feature_types'

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Show those genes that yield the highest fraction of counts in each single cell, across all cells.

# %%
sc.pl.highest_expr_genes(adata, n_top=20, width =0.8, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %% [markdown]
# Basic filtering:

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# filtered out 105 cells that have less than 200 genes expressed
# filtered out 15005 genes that are detected in less than 3 cells

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1510 × 21596
#     obs: 'n_genes'
#     var: 'gene_ids', 'feature_types', 'n_cells'

# %% [markdown]
# Let's assemble some information about mitochondrial genes, which are important for quality control.
#
# Citing from "Simple Single Cell" workflows [(Lun, McCarthy & Marioni, 2017)](https://master.bioconductor.org/packages/release/workflows/html/simpleSingleCell.html#examining-gene-level-metrics):
#
# > High proportions are indicative of poor-quality cells (Islam et al. 2014; Ilicic et al. 2016), possibly because of loss of cytoplasmic RNA from perforated cells. The reasoning is that mitochondria are larger than individual transcript molecules and less likely to escape through tears in the cell membrane.

# %% [markdown]
# With `pp.calculate_qc_metrics`, we can compute many metrics very efficiently.

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %% [markdown]
# A violin plot of some of the computed quality measures:
#
# * the number of genes expressed in the count matrix
# * the total counts per cell
# * the percentage of counts in mitochondrial genes

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %% [markdown]
# Remove cells that have too many mitochondrial genes expressed or too many total counts:

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %% [markdown]
# Actually do the filtering by slicing the `AnnData` object.

# %%
adata_temp = adata

# %%
adata = adata_temp

# %%
adata.obs.n_genes_by_counts
# Out:
# AAACCCACATGTGTCA-1    2821
# AAACGAAAGAGAACCC-1    3501
# AAACGCTAGATTAGAC-1    1365
# AAACGCTGTACGCTAT-1    4350
# AAAGAACAGTACAGCG-1    2778
#                       ...
# TTTGGAGCACTGGAAG-1    3308
# TTTGGAGTCGGTCACG-1     352
# TTTGGTTCAAATGAGT-1     510
# TTTGGTTTCATCTACT-1    3281
# TTTGTTGTCAGATTGC-1    3638
# Name: n_genes_by_counts, Length: 1510, dtype: int32

# %%
adata = adata[adata.obs.n_genes_by_counts < 5000, :]
adata = adata[adata.obs.pct_counts_mt < 5, :]

# %% [markdown]
# Total-count normalize (library-size correct) the data matrix $\mathbf{X}$ to 10,000 reads per cell, so that counts become comparable among cells.

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# normalizing counts per cell
#     finished ({time_passed})
# D:\Anaconda\lib\site-packages\scanpy\preprocessing\_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# Logarithmize the data:

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 476 × 21596
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pp.log1p(adata)

# %% [markdown]
# Identify highly-variable genes.

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata)

# %% [markdown]
# Set the `.raw` attribute of the AnnData object to the normalized and logarithmized raw gene expression for later use in differential testing and visualizations of gene expression. This simply freezes the state of the AnnData object.

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# You can get back an `AnnData` of the object in `.raw` by calling `.raw.to_adata()`.
#
# </div>

# %%
adata.raw = adata

# %% [markdown]
# <div class="alert alert-info">
#
# **Note**
#
# If you don't proceed below with correcting the data with `sc.pp.regress_out` and scaling it via `sc.pp.scale`, you can also get away without using `.raw` at all.
#
# The result of the previous highly-variable-genes detection is stored as an annotation in `.var.highly_variable` and auto-detected by PCA and hence, `sc.pp.neighbors` and subsequent manifold/graph tools. In that case, the step *actually do the filtering* below is unnecessary, too.
#
# </div>

# %% [markdown]
# Actually do the filtering

# %%
adata = adata[:, adata.var.highly_variable]

# %% [markdown]
# Regress out effects of total counts per cell and the percentage of mitochondrial genes expressed. Scale the data to unit variance.

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:17)

# %% [markdown]
# Scale each gene to unit variance. Clip values exceeding standard deviation 10.

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# ## Principal component analysis

# %% [markdown]
# Reduce the dimensionality of the data by running principal component analysis (PCA), which reveals the main axes of variation and denoises the data.

# %%
sc.tl.pca(adata, svd_solver='arpack')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:00)

# %% [markdown]
# We can make a scatter plot in the PCA coordinates, but we will not use that later on.

# %%
sc.set_figure_params(figsize = (10, 10))
sc.pl.pca(adata, color='CST3', title='PCA' )

# %% [markdown]
# Let us inspect the contribution of single PCs to the total variance in the data. This gives us information about how many PCs we should consider in order to compute the neighborhood relations of cells, e.g. used in the clustering function  `sc.tl.louvain()` or tSNE `sc.tl.tsne()`. In our experience, often a rough estimate of the number of PCs does fine.

# %%
sc.set_figure_params(figsize = (5, 5), fontsize = 20)
sc.pl.pca_variance_ratio(adata, log=True)

# %% [markdown]
# Save the result.

# %%
results_file
# Out:
# 'write/2K_Brain_Tumor_filtered_feature_bc_matrix.h5ad'

# %%
adata.write(results_file)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 476 × 4713
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %% [markdown]
# ## Computing the neighborhood graph

# %% [markdown]
# Let us compute the neighborhood graph of cells using the PCA representation of the data matrix. You might simply use default values here. For the sake of reproducing Seurat's results, let's take the following values.

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)

# %% [markdown]
# ## Embedding the neighborhood graph

# %% [markdown]
# We suggest embedding the graph in two dimensions using UMAP ([McInnes et al., 2018](https://arxiv.org/abs/1802.03426)), see below. It is potentially more faithful to the global connectivity of the manifold than tSNE, i.e., it better preserves trajectories. In some ocassions, you might still observe disconnected clusters and similar connectivity violations. They can usually be remedied by running:
#
# ```
# tl.paga(adata)
# pl.paga(adata, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
# tl.umap(adata, init_pos='paga')
# ```

# %%
sc.tl.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 476 × 4713
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.set_figure_params(figsize = (10, 7.5))
sc.pl.umap(adata, color=['CST3'], title = 'UMAP projected clustering')

# %% [markdown]
# As we set the `.raw` attribute of `adata`, the previous plots showed the "raw" (normalized, logarithmized, but uncorrected) gene expression. You can also plot the scaled and corrected gene expression by explicitly stating that you don't want to use `.raw`.

# %% [markdown]
# ## Clustering the neighborhood graph

# %% [markdown]
# As with Seurat and many other frameworks, we recommend the Leiden graph-clustering method (community detection based on optimizing modularity) by [Traag *et al.* (2018)](https://scanpy.readthedocs.io/en/latest/references.html#traag18). Note that Leiden clustering directly clusters the neighborhood graph of cells, which we already computed in the previous section.

# %%
sc.tl.leiden(adata)
# Out:
# running Leiden clustering
#     finished: found 12 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %% [markdown]
# Plot the clusters, which agree quite well with the result of Seurat.

# %%
sc.pl.umap(adata, color=['leiden'])

# %% [markdown]
# Save the result.

# %%
adata.write(results_file)

# %% [markdown]
# ## Finding marker genes

# %% [markdown]
# Let us compute a ranking for the highly differential genes in each cluster. For this, by default, the `.raw` attribute of AnnData is used in case it has been initialized before. The simplest and fastest method to do so is the t-test.

# %%
sc.set_figure_params(figsize = (5, 5))
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
sc.pl.rank_genes_groups(adata, n_genes=15, sharey=False)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:00)

# %%
sc.settings.verbosity = 2  # reduce the verbosity

# %% [markdown]
# The result of a [Wilcoxon rank-sum (Mann-Whitney-U)](https://en.wikipedia.org/wiki/Mann%E2%80%93Whitney_U_test) test is very similar. We recommend using the latter in publications, see e.g., [Sonison & Robinson (2018)](https://doi.org/10.1038/nmeth.4612). You might also consider much more powerful differential testing packages like MAST, limma, DESeq2 and, for python, the recent diffxpy.

# %%
sc.set_figure_params(fontsize = 3)
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=10, sharey=False)
# Out:
# ranking genes
#     finished (0:00:01)

# %% [markdown]
# Save the result.

# %%
adata.write(results_file)

# %% [markdown]
# As an alternative, let us rank genes using logistic regression. For instance, this has been suggested by [Natranos et al. (2018)](https://doi.org/10.1101/258566). The essential difference is that here, we use a multi-variate appraoch whereas conventional differential tests are uni-variate. [Clark et al. (2014)](https://doi.org/10.1186/1471-2105-15-79) has more details.

# %%
sc.set_figure_params(figsize = (5, 5))

sc.tl.rank_genes_groups(adata, 'leiden', method='logreg')
sc.pl.rank_genes_groups(adata, n_genes=15, sharey=False)
# Out:
# ranking genes
#     finished (0:00:05)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
pd.DataFrame(adata.uns['rank_genes_groups']['names']).head(20)
# Out:
#            0          1         2        3        4           5         6  \
# 0      VEGFA       CST3       LYZ     SPP1    APOC2  AC009041.2   S100A10
# 1     AKAP12        MT3      AREG    APOC2    CXCL8        DLL3     NUPR1
# 2      NDRG1       EGFR    S100A4     AIF1   CCL4L2        CD24      RGCC
# 3     IGFBP5      NOVA1      CREM     HAMP     IER3       OLIG1     APOC1
# 4     IGFBP2     PTPRZ1    HSPA1A    GNG10      FOS       TUBB3       FTL
# 5       NRN1       BCHE      CD44  ALOX5AP    CH25H       SOX11      APOE
# 6   NDUFA4L2    FAM181B     ANXA1     BIN1    OTUD1        SOX4     PLIN2
# 7      EPAS1  LINC01445      EREG     C1QA   CHMP1B       GPM6A      CSTB
# 8     ERRFI1      PDGFA    ZNF331     C1QB      JUN        SOX6       VIM
# 9    SPARCL1       BCAN       AHR     SCIN     EGR1         TNR   S100A11
# 10      ENO2      FABP5     CXCR4    FCGBP     BTG2         SHD      FTH1
# 11     PLOD2       SOX4     TIMP1   S100A9    H3F3B      GLCCI1    LGALS1
# 12     TIMP3    TSC22D1  HLA-DQB1       C3    DUSP1     GADD45G      CTSD
# 13   SLC16A1        CKB  HLA-DQA1   S100A8   CCL3L1      TUBA1A      SPP1
# 14    IGFBP3        VIM     CXCL2     ACTB  ZFAND2A       NCAM1       SMS
# 15     OLFM1      GRIA2  HLA-DRB5     CCL3    DDIT4       MEX3A     ANXA2
# 16      PGK1       CHL1    HSPA1B  RNASET2   NFKBIA        JPT1  C15orf48
# 17      CCN1    TSPAN12      CD52    RGS16    NR4A2        SOX8    S100A6
# 18    CHI3L1       CD63     HMOX1    GPR34     IER2        PFN2    FCER1G
# 19    TENT5A       CDK6   S100A10    CALM2     RGS2      DPYSL3     GPNMB
#
#            7        8        9        10        11
# 0       MT2A   MALAT1    PTGDS      GFAP     HMGB2
# 1     SEC61G     SPP1     PLP1    CHI3L1     CENPF
# 2       MT1X     RGCC   NKX6-2      AQP4     UBE2S
# 3      CRYAB   SNHG12    CRYAB       ID3     TOP2A
# 4      S100B    HSPA6     QDPR       CLU     PTTG1
# 5   MARCKSL1    FABP5      MBP     CRYAB    TUBA1B
# 6      PPDPF    NUPR1       TF     ITM2C     HMGN2
# 7       PTMS    GPNMB      GSN  SERPINA3  HIST1H4C
# 8      PEBP1      LPL     GLUL        F3    NUSAP1
# 9      RAB13    MGAT1    APLP1       ID1     H2AFZ
# 10    IGFBP5   SLC2A5   S100A1      CNN3      CKS2
# 11       MT3   RNASE4    CNDP1   S100A10     CCNB2
# 12   SLC25A6     WSB1   DBNDD2     FABP7     BIRC5
# 13      TPM2     MSR1     ERMN    S100A6    MAD2L1
# 14     GPM6B    FOXO3  SELENOP   C1orf61     CCNB1
# 15     RPL29    GAPDH     SGK1      SOD2      PRC1
# 16    CHI3L1      MIF   CLDND1   SPARCL1    LGALS1
# 17   TSC22D4    NEAT1      SCD     NAMPT     UBE2T
# 18     GSTP1    TMED5      MAG      CD44     HMGB1
# 19       DBI  SLC11A1     KLK6    IFITM3       PBK

# %% [markdown]
# With the exceptions of *IL7R*, which is only found by the t-test and *FCER1A*, which is only found by the other two appraoches, all marker genes are recovered in all approaches.
#
# Louvain Group | Markers | Cell Type
# ---|---|---
# 0 | IL7R | CD4 T cells
# 1 | CD14, LYZ | CD14+ Monocytes
# 2 | MS4A1 |	B cells
# 3 | CD8A |	CD8 T cells
# 4 | GNLY, NKG7 | 	NK cells
# 5 | FCGR3A, MS4A7 |	FCGR3A+ Monocytes
# 6 | FCER1A, CST3 |	Dendritic Cells
# 7 | PPBP |	Megakaryocytes

# %% [markdown]
# Let us also define a list of marker genes for later reference.

# %%
marker_genes = ['IL7R', 'CD79A', 'MS4A1', 'CD8A', 'CD8B', 'LYZ', 'CD14',
                'LGALS3', 'S100A8', 'GNLY', 'NKG7', 'KLRB1',  
                'FCGR3A', 'MS4A7', 'FCER1A', 'CST3', 'PPBP']

# %% [markdown]
# Reload the object that has been save with the Wilcoxon Rank-Sum test result.

# %%
adata = sc.read(results_file)

# %% [markdown]
# Show the 10 top ranked genes per cluster 0, 1, ..., 7 in a dataframe.

# %%
pd.DataFrame(adata.uns['rank_genes_groups']['names']).head(5)
# Out:
#          0       1     2       3        4       5        6       7
# 0   SEC61G   NEAT1  AIF1   NUPR1     CKLF    DDX5  MT-ATP6     LCK
# 1   IGFBP2  MALAT1  C1QC    CSTB     ACTB  SRGAP2      FTL    CD3E
# 2  C1orf61    WSB1  C1QA     FTL  ARHGDIB   GRID2     SPP1  TUBA4A
# 3      PTN  HSPA1B  C1QB    FTH1     GMFG   NEAT1    LAMP1   CXCR4
# 4   TUBB2B   RBM39  ACTB  LGALS1      SRI   LPAR6     CTSD    BTG1

# %% [markdown]
# Get a table with the scores and groups.

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'pvals']}).head(5)
# Out:
#        0_n           0_p     1_n           1_p   2_n           2_p     3_n  \
# 0   SEC61G  3.586990e-17   NEAT1  9.144574e-13  AIF1  1.645888e-11   NUPR1
# 1   IGFBP2  6.049690e-13  MALAT1  3.367115e-12  C1QC  3.736692e-11    CSTB
# 2  C1orf61  9.128411e-13    WSB1  1.664799e-10  C1QA  5.102759e-11     FTL
# 3      PTN  4.654889e-12  HSPA1B  1.088345e-09  C1QB  7.171391e-11    FTH1
# 4   TUBB2B  1.695392e-11   RBM39  1.103130e-09  ACTB  2.145911e-10  LGALS1
#
#             3_p      4_n       4_p     5_n       5_p      6_n       6_p  \
# 0  9.863539e-13     CKLF  0.000021    DDX5  0.000001  MT-ATP6  0.000103
# 1  1.034088e-11     ACTB  0.000027  SRGAP2  0.000005      FTL  0.000352
# 2  1.265803e-11  ARHGDIB  0.000047   GRID2  0.000006     SPP1  0.000447
# 3  3.216211e-11     GMFG  0.000066   NEAT1  0.000006    LAMP1  0.000574
# 4  8.288325e-11      SRI  0.000074   LPAR6  0.000010     CTSD  0.000697
#
#       7_n       7_p
# 0     LCK  0.000150
# 1    CD3E  0.000176
# 2  TUBA4A  0.000206
# 3   CXCR4  0.000231
# 4    BTG1  0.000249

# %% [markdown]
# Compare to a single cluster:

# %%
adata.uns['log1p']
# Out:
# {}

# %%
sc.tl.rank_genes_groups(adata, 'leiden', groups=['0'], reference='1', method='wilcoxon')
sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
# Out:
# ranking genes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 sc.tl.rank_genes_groups(adata, 'leiden', groups=['0'], reference='1', method='wilcoxon')
#       2 sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
#
# File D:\Anaconda\lib\site-packages\scanpy\tools\_rank_genes_groups.py:590, in rank_genes_groups(adata, groupby, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     580 adata.uns[key_added] = {}
#     581 adata.uns[key_added]['params'] = dict(
#     582     groupby=groupby,
#     583     reference=reference,
#    (...)
#     587     corr_method=corr_method,
#     588 )
# --> 590 test_obj = _RankGenes(adata, groups_order, groupby, reference, use_raw, layer, pts)
#     592 if check_nonnegative_integers(test_obj.X) and method != 'logreg':
#     593     logg.warning(
#     594         "It seems you use rank_genes_groups on the raw count data. "
#     595         "Please logarithmize your data before calling rank_genes_groups."
#     596     )
#
# File D:\Anaconda\lib\site-packages\scanpy\tools\_rank_genes_groups.py:93, in _RankGenes.__init__(self, adata, groups, groupby, reference, use_raw, layer, comp_pts)
#      82 def __init__(
#      83     self,
#      84     adata,
#    (...)
#      90     comp_pts=False,
#      91 ):
# ---> 93     if 'log1p' in adata.uns_keys() and adata.uns['log1p']['base'] is not None:
#      94         self.expm1_func = lambda x: np.expm1(x * np.log(adata.uns['log1p']['base']))
#      95     else:
#
# KeyError: 'base'

# %% [markdown]
# If we want a more detailed view for a certain group, use `sc.pl.rank_genes_groups_violin`.

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
#
# File D:\Anaconda\lib\site-packages\scanpy\plotting\_tools\__init__.py:1152, in rank_genes_groups_violin(adata, groups, n_genes, gene_names, gene_symbols, use_raw, key, split, scale, strip, jitter, size, ax, show, save)
#    1150 for group_name in groups_names:
#    1151     if gene_names is None:
# -> 1152         _gene_names = adata.uns[key]['names'][group_name][:n_genes]
#    1153     else:
#    1154         _gene_names = gene_names
#
# KeyError: 'names'

# %% [markdown]
# Reload the object with the computed differential expression (i.e. DE via a comparison with the rest of the groups):

# %%
adata = sc.read(results_file)

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)

# %% [markdown]
# If you want to compare a certain gene across groups, use the following.

# %%
sc.pl.violin(adata, ['CST3', 'NKG7'], groupby='leiden')

# %% [markdown]
# Actually mark the cell types.

# %%
new_cluster_names = [
    'CD4 T', 'CD14 Monocytes',
    'B', 'CD8 T', 
    'NK', 'FCGR3A Monocytes',
    'Dendritic', 'Megakaryocytes']
adata.rename_categories('leiden', new_cluster_names)
# Out:
# D:\Anaconda\lib\site-packages\anndata\_core\anndata.py:1160: FutureWarning: The `inplace` parameter in pandas.Categorical.rename_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   self.obs[key].cat.rename_categories(categories, inplace=True)

# %%
sc.pl.umap(adata, color='leiden', legend_loc='on data', title='', frameon=False, save='.pdf')
# Out:
# WARNING: saving figure to file figures\umap.pdf

# %% [markdown]
# Now that we annotated the cell types, let us visualize the marker genes.

# %%
sc.pl.dotplot(adata, marker_genes, groupby='leiden');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 sc.pl.dotplot(adata, marker_genes, groupby='leiden')
#
# File D:\Anaconda\lib\site-packages\scanpy\plotting\_dotplot.py:942, in dotplot(adata, var_names, groupby, use_raw, log, num_categories, expression_cutoff, mean_only_expressed, cmap, dot_max, dot_min, standard_scale, smallest_dot, title, colorbar_title, size_title, figsize, dendrogram, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, swap_axes, dot_color_df, show, save, ax, return_fig, vmin, vmax, vcenter, norm, **kwds)
#     939 if 'color_map' in kwds:
#     940     del kwds['color_map']
# --> 942 dp = DotPlot(
#     943     adata,
#     944     var_names,
#     945     groupby,
#     946     use_raw=use_raw,
#     947     log=log,
#     948     num_categories=num_categories,
#     949     expression_cutoff=expression_cutoff,
#     950     mean_only_expressed=mean_only_expressed,
#     951     standard_scale=standard_scale,
#     952     title=title,
#     953     figsize=figsize,
#     954     gene_symbols=gene_symbols,
#     955     var_group_positions=var_group_positions,
#     956     var_group_labels=var_group_labels,
#     957     var_group_rotation=var_group_rotation,
#     958     layer=layer,
#     959     dot_color_df=dot_color_df,
#     960     ax=ax,
#     961     vmin=vmin,
#     962     vmax=vmax,
#     963     vcenter=vcenter,
#     964     norm=norm,
#     965     **kwds,
#     966 )
#     968 if dendrogram:
#     969     dp.add_dendrogram(dendrogram_key=dendrogram)
#
# File D:\Anaconda\lib\site-packages\scanpy\plotting\_dotplot.py:132, in DotPlot.__init__(self, adata, var_names, groupby, use_raw, log, num_categories, categories_order, title, figsize, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, expression_cutoff, mean_only_expressed, standard_scale, dot_color_df, dot_size_df, ax, vmin, vmax, vcenter, norm, **kwds)
#     104 def __init__(
#     105     self,
#     106     adata: AnnData,
#    (...)
#     130     **kwds,
#     131 ):
# --> 132     BasePlot.__init__(
#     133         self,
#     134         adata,
#     135         var_names,
#     136         groupby,
#     137         use_raw=use_raw,
#     138         log=log,
#     139         num_categories=num_categories,
#     140         categories_order=categories_order,
#     141         title=title,
#     142         figsize=figsize,
#     143         gene_symbols=gene_symbols,
#     144         var_group_positions=var_group_positions,
#     145         var_group_labels=var_group_labels,
#     146         var_group_rotation=var_group_rotation,
#     147         layer=layer,
#     148         ax=ax,
#     149         vmin=vmin,
#     150         vmax=vmax,
#     151         vcenter=vcenter,
#     152         norm=norm,
#     153         **kwds,
#     154     )
#     156     # for if category defined by groupby (if any) compute for each var_name
#     157     # 1. the fraction of cells in the category having a value >expression_cutoff
#     158     # 2. the mean value over the category
#     159
#     160     # 1. compute fraction of cells having value > expression_cutoff
#     161     # transform obs_tidy into boolean matrix using the expression_cutoff
#     162     obs_bool = self.obs_tidy > expression_cutoff
#
# File D:\Anaconda\lib\site-packages\scanpy\plotting\_baseplot_class.py:111, in BasePlot.__init__(self, adata, var_names, groupby, use_raw, log, num_categories, categories_order, title, figsize, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, ax, vmin, vmax, vcenter, norm, **kwds)
#     103 self.has_var_groups = (
#     104     True
#     105     if var_group_positions is not None and len(var_group_positions) > 0
#     106     else False
#     107 )
#     109 self._update_var_groups()
# --> 111 self.categories, self.obs_tidy = _prepare_dataframe(
#     112     adata,
#     113     self.var_names,
#     114     groupby,
#     115     use_raw,
#     116     log,
#     117     num_categories,
#     118     layer=layer,
#     119     gene_symbols=gene_symbols,
#     120 )
#     121 if len(self.categories) > self.MAX_NUM_CATEGORIES:
#     122     warn(
#     123         f"Over {self.MAX_NUM_CATEGORIES} categories found. "
#     124         "Plot would be very large."
#     125     )
#
# File D:\Anaconda\lib\site-packages\scanpy\plotting\_anndata.py:1927, in _prepare_dataframe(adata, var_names, groupby, use_raw, log, num_categories, layer, gene_symbols)
#    1925     groupby.remove(groupby_index)
#    1926 keys = list(groupby) + list(np.unique(var_names))
# -> 1927 obs_tidy = get.obs_df(
#    1928     adata, keys=keys, layer=layer, use_raw=use_raw, gene_symbols=gene_symbols
#    1929 )
#    1930 assert np.all(np.array(keys) == np.array(obs_tidy.columns))
#    1932 if groupby_index is not None:
#    1933     # reset index to treat all columns the same way.
#
# File D:\Anaconda\lib\site-packages\scanpy\get\get.py:272, in obs_df(adata, keys, obsm_keys, layer, gene_symbols, use_raw)
#     269 else:
#     270     alias_index = None
# --> 272 obs_cols, var_idx_keys, var_symbols = _check_indices(
#     273     adata.obs,
#     274     var.index,
#     275     "obs",
#     276     keys,
#     277     alias_index=alias_index,
#     278     use_raw=use_raw,
#     279 )
#     281 # Make df
#     282 df = pd.DataFrame(index=adata.obs_names)
#
# File D:\Anaconda\lib\site-packages\scanpy\get\get.py:167, in _check_indices(dim_df, alt_index, dim, keys, alias_index, use_raw)
#     165         not_found.append(key)
#     166 if len(not_found) > 0:
# --> 167     raise KeyError(
#     168         f"Could not find keys '{not_found}' in columns of `adata.{dim}` or in"
#     169         f" {alt_repr}.{alt_search_repr}."
#     170     )
#     172 return col_keys, index_keys, index_aliases
#
# KeyError: "Could not find keys '['PPBP']' in columns of `adata.obs` or in adata.raw.var_names."

# %% [markdown]
# There is also a very compact violin plot.

# %%
sc.pl.stacked_violin(adata, marker_genes, groupby='leiden', rotation=90);

# %% [markdown]
# During the course of this analysis, the AnnData accumlated the following annotations.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.write(results_file, compression='gzip')  # `compression='gzip'` saves disk space, but slows down writing and subsequent reading

# %% [markdown]
# Get a rough overview of the file using `h5ls`, which has many options - for more details see [here](https://github.com/theislab/scanpy_usage/blob/master/170505_seurat/info_h5ad.md). The file format might still be subject to further optimization in the future. All reading functions will remain backwards-compatible, though.

# %% [markdown]
# If you want to share this file with people who merely want to use it for visualization, a simple way to reduce the file size is by removing the dense scaled and corrected data matrix. The file still contains the raw data used in the visualizations in `adata.raw`.

# %%
adata.raw.to_adata().write('./write/pbmc3k_withoutX.h5ad')

# %% [markdown]
# If you want to export to "csv", you have the following options:

# %%
# Export single fields of the annotation of observations
# adata.obs[['n_counts', 'louvain_groups']].to_csv(
#     './write/pbmc3k_corrected_louvain_groups.csv')

# Export single columns of the multidimensional annotation
# adata.obsm.to_df()[['X_pca1', 'X_pca2']].to_csv(
#     './write/pbmc3k_corrected_X_pca.csv')

# Or export everything except the data using `.write_csvs`.
# Set `skip_data=False` if you also want to export the data.
# adata.write_csvs(results_file[:-5], )
